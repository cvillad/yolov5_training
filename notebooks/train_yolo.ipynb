# %% [markdown]
# ## Building and pushing image to an EC Repository

# %%
# !cd .. && scripts/build_and_push.sh
# Out:
# scripts/build_and_push.sh: line 1: ·!/bin/bash: No such file or directory
# ECR Login
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Building image
# Sending build context to Docker daemon  2.457GB
# Step 1/9 : FROM nvcr.io/nvidia/pytorch:20.08-py3
#  ---> c710aa2340b4
# Step 2/9 : ENV PYTHONDONTWRITEBYTECODE=1
#  ---> Using cache
#  ---> 856cd9c0126f
# Step 3/9 : ENV PYTHONUNBUFFERED=1
#  ---> Using cache
#  ---> c56d3042c81a
# Step 4/9 : RUN apt-get update && apt-get install -y --no-install-recommends nginx curl
#  ---> Using cache
#  ---> 9f9821291e14
# Step 5/9 : WORKDIR /opt/ml/
#  ---> Using cache
#  ---> 3b56b46fe6a0
# Step 6/9 : RUN pip install sagemaker-training
#  ---> Using cache
#  ---> 6327a4ef2c30
# Step 7/9 : COPY src/ /opt/ml/code/
#  ---> Using cache
#  ---> 96097d37c455
# Step 8/9 : ENV SAGEMAKER_PROGRAM train
#  ---> Using cache
#  ---> 15c67852cb4c
# Step 9/9 : ENV PATH="/opt/ml/code:${PATH}"
#  ---> Using cache
#  ---> 884bf3236c35
# Successfully built 884bf3236c35
# Successfully tagged train:latest
# Pushing to ECR
# The push refers to repository [430127992102.dkr.ecr.us-west-2.amazonaws.com/yolov5_train]
#
# 3934f1bb: Preparing
# b5beec64: Preparing
# 6833b6f9: Preparing
# cbe57ed4: Preparing
# 535cf0b1: Preparing
# f2fc23be: Preparing
# f1144bfa: Preparing
# 4a3f2ae3: Preparing
# 8bfdeee7: Preparing
# bedfd29d: Preparing
# 3a848754: Preparing
# 79876d58: Preparing
# 6cc777e6: Preparing
# 481d042b: Preparing
# 2d1617bd: Preparing
# 5b178613: Preparing
# 20ece1bb: Preparing
# d45c9936: Preparing
# bcc85b52: Preparing
# 1df9aa18: Preparing
# 757968f7: Preparing
# c8ca60ec: Preparing
# 01b6160f: Preparing
# 08e715aa: Preparing
# 38ca324c: Preparing
# 05efbb85: Preparing
# ef29593c: Preparing
# c1b005d0: Preparing
# 3347c77e: Preparing
# 73b91957: Preparing
# 6bba3a54: Preparing
# d305b6fe: Preparing
# 34539c4b: Preparing
# 8e883ce0: Preparing
# 3105ea49: Preparing
# fd860433: Preparing
# 196d29b9: Preparing
# dc9d77d9: Preparing
# 87a0f336: Preparing
# 76287df5: Preparing
# 7aea68cd: Preparing
# 1ccf7ee0: Preparing
# 51c2f8ad: Preparing
# 2a1a6205: Preparing
# 546ec635: Preparing
# 8b3c8971: Preparing
# 3a2b059b: Preparing
# 30055b29: Preparing
# f1b5f44c: Preparing
# b917ef50: Preparing
# 3c4877ef: Preparing
# b71a5be7: Preparing
# 4487ecb7: Preparing
# 5173a9ae: Preparing
# c169ba53: Preparing
# 36b4dc3d: Preparing
# 877f8a1f: Preparing
# 146f5dbd: Preparing
# f9a74649: Preparing
# da143c91: Preparing
# 287e1f04: Preparing
# 68776582: Layer already exists latest: digest: sha256:2122e4a34e8194e48f7c4deb65a9b4ad4182ee2e27d8d8b8a44cedbeffb34ed8 size: 13338

# %% [markdown]
# ## Sagemaker config

# %%
from sagemaker.session import get_execution_role, Session
import os

sagemaker_role = get_execution_role()
sagemaker_session = Session()

# %%
from time import gmtime, strftime

bucket_name = sagemaker_session.default_bucket()
key_name = "TiendaApp"
s3_uri_data = "s3://{}/{}/{}/".format(bucket_name, key_name, "data")
s3_uri_output = "s3://{}/{}/{}/".format(bucket_name, key_name, "model")
s3_uri_checkpoint = "s3://{}/{}/{}".format(bucket_name, key_name, "checkpoints")
s3_output_path_tensorboard = "s3://{}/{}/{}".format(bucket_name, key_name, "tensorboard")

account = sagemaker_session.boto_session.client('sts').get_caller_identity()['Account']
region = sagemaker_session.boto_session.region_name
image_name = "yolov5_train"
image_uri = "{0}.dkr.ecr.{1}.amazonaws.com/{2}".format(account, region, image_name)

base_job_name = "test-training-job-{}".format(strftime("%Y-%m-%d-%H-%M-%S", gmtime()))
os.environ["account"] = account
os.environ["s3_uri"] = s3_uri_data

print("Training Job name : {}".format(base_job_name))
print("S3 uri input: {}".format(s3_uri_data))
print("S3 uri output: {}".format(s3_uri_output))
print("image uri: {}".format(image_uri))
#!aws s3 ls $s3_uri
#!aws ecr describe-repositories --registry-id $account
# Out:
# Training Job name : test-training-job-2020-09-21-20-33-22
# S3 uri input: s3://sagemaker-us-west-2-430127992102/TiendaApp/data/
# S3 uri output: s3://sagemaker-us-west-2-430127992102/TiendaApp/model/
# image uri: 430127992102.dkr.ecr.us-west-2.amazonaws.com/yolov5_train

# %% [markdown]
# ## Starting a sagemaker training job

# %%
from sagemaker.estimator import Estimator
from sagemaker.debugger import TensorBoardOutputConfig

tensorboard_output_config = TensorBoardOutputConfig(
    s3_output_path=s3_output_path_tensorboard,
    container_local_output_path="/opt/ml/output/tensorboard"
)

metric_definitions = [{"Name": "train:error", "Regex": "\S*train_error=([0-9\.]+)"},
                     {"Name": "val:error", "Regex": "\S*val_error=([0-9\\.]+)"}]
checkpoint_local_path = "/opt/ml/checkpoints/"

yolov3_estimator = Estimator(image_name=image_uri, 
                            role=sagemaker_role,
                             output_path=s3_uri_output,
                            train_instance_count=2,
                           train_instance_type="ml.g4dn.xlarge",
                            train_volume_size=35,
                            sagemaker_session=sagemaker_session,
                             tensorboard_output_config = tensorboard_output_config,
                             enable_sagemaker_metrics = True,
                             metric_definitions = metric_definitions,
                             checkpoint_s3_uri = s3_uri_checkpoint,
                             checkpoint_local_path = checkpoint_local_path,
                            base_job_name = base_job_name,
                            hyperparameters={"test": "this is a test", "batch": 32},
                            tags=[{"Key": "Name", "Value": "test-job"},
                                 {"Key": "Description", "Value": "Test training job"}])


#yolov3_estimator.fit(job_name=base_job_name, wait=True)
yolov3_estimator.fit(inputs={"training": s3_uri_data}, job_name=base_job_name, wait=True)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-09-21 20:33:23 Starting - Starting the training job...
# 2020-09-21 20:33:26 Starting - Launching requested ML instances......
# 2020-09-21 20:34:36 Starting - Preparing the instances for training......
# 2020-09-21 20:35:30 Downloading - Downloading input data......
# 2020-09-21 20:36:38 Training - Downloading the training image......................=============
# == PyTorch ==
# =============
#
# NVIDIA Release 20.08 (build 15516749)
# PyTorch Version 1.7.0a0+8deb4fe
#
# Container image Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#
# Copyright (c) 2014-2020 Facebook Inc.
# Copyright (c) 2011-2014 Idiap Research Institute (Ronan Collobert)
# Copyright (c) 2012-2014 Deepmind Technologies    (Koray Kavukcuoglu)
# Copyright (c) 2011-2012 NEC Laboratories America (Koray Kavukcuoglu)
# Copyright (c) 2011-2013 NYU                      (Clement Farabet)
# Copyright (c) 2006-2010 NEC Laboratories America (Ronan Collobert, Leon Bottou, Iain Melvin, Jason Weston)
# Copyright (c) 2006      Idiap Research Institute (Samy Bengio)
# Copyright (c) 2001-2004 Idiap Research Institute (Ronan Collobert, Samy Bengio, Johnny Mariethoz)
# Copyright (c) 2015      Google Inc.
# Copyright (c) 2015      Yangqing Jia
# Copyright (c) 2013-2016 The Caffe contributors
# All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION.  All rights reserved.
# NVIDIA modifications are covered by the license terms that apply to the underlying project or file.
#
# NOTE: Legacy NVIDIA Driver detected.  Compatibility mode ENABLED.
#
# NOTE: MOFED driver for multi-node communication was not detected.
#       Multi-node communication performance may be reduced.
#
# 2020-09-21 20:40:30,645 - INFO - Container structure
# 2020-09-21 20:40:30,645 - DEBUG - /opt/ml/output
# 2020-09-21 20:40:30,645 - DEBUG - /opt/ml/model
# 2020-09-21 20:40:30,645 - DEBUG - /opt/ml/checkpoints
# 2020-09-21 20:40:30,645 - DEBUG - /opt/ml/code
# 2020-09-21 20:40:30,645 - DEBUG - /opt/ml/input
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/output/data
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/output/profiler
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/output/tensorboard
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/output/metrics
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/output/metrics/sagemaker
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/checkpoints/ckpt_epoch1.pt
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/checkpoints/ckpt_epoch0.pt
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/checkpoints/ckpt.pt
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/checkpoints/ckpt_epoch4.pt
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/yolov5
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/train
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/test.py
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/yolov5/weights
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/yolov5/utils
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/yolov5/models
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/yolov5/detect.py
# 2020-09-21 20:40:30,646 - DEBUG - /opt/ml/code/yolov5/train.py
# 2020-09-21 20:40:30,649 - DEBUG - /opt/ml/input/config/upstreamoutputdataconfig.json
# 2020-09-21 20:40:30,650 - DEBUG - /opt/ml/input/config/checkpointconfig.json
# 2020-09-21 20:40:30,650 - DEBUG - /opt/ml/input/data/training
# 2020-09-21 20:40:30,650 - DEBUG - /opt/ml/input/data/checkpoints-manifest
# 2020-09-21 20:40:30,650 - DEBUG - /opt/ml/input/data/training/validating
# 2020-09-21 20:40:30,650 - DEBUG - /opt/ml/input/data/training/training
# 2020-09-21 20:40:30,669 - INFO - Running training script
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# =============
# == PyTorch ==
# =============
#
# NVIDIA Release 20.08 (build 15516749)
# PyTorch Version 1.7.0a0+8deb4fe
#
# Container image Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#
# Copyright (c) 2014-2020 Facebook Inc.
# Copyright (c) 2011-2014 Idiap Research Institute (Ronan Collobert)
# Copyright (c) 2012-2014 Deepmind Technologies    (Koray Kavukcuoglu)
# Copyright (c) 2011-2012 NEC Laboratories America (Koray Kavukcuoglu)
# Copyright (c) 2011-2013 NYU                      (Clement Farabet)
# Copyright (c) 2006-2010 NEC Laboratories America (Ronan Collobert, Leon Bottou, Iain Melvin, Jason Weston)
# Copyright (c) 2006      Idiap Research Institute (Samy Bengio)
# Copyright (c) 2001-2004 Idiap Research Institute (Ronan Collobert, Samy Bengio, Johnny Mariethoz)
# Copyright (c) 2015      Google Inc.
# Copyright (c) 2015      Yangqing Jia
# Copyright (c) 2013-2016 The Caffe contributors
# All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION.  All rights reserved.
# NVIDIA modifications are covered by the license terms that apply to the underlying project or file.
#
# NOTE: Legacy NVIDIA Driver detected.  Compatibility mode ENABLED.
#
# NOTE: MOFED driver for multi-node communication was not detected.
#       Multi-node communication performance may be reduced.
#
# 2020-09-21 20:40:33,300 - INFO - Container structure
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/output
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/model
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/checkpoints
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/code
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/input
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/output/profiler
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/output/tensorboard
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/output/metrics
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/output/data
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/output/metrics/sagemaker
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/checkpoints/ckpt_epoch1.pt
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/checkpoints/ckpt.pt
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/checkpoints/ckpt_epoch4.pt
# 2020-09-21 20:40:33,301 - DEBUG - /opt/ml/checkpoints/ckpt_epoch0.pt
# 2020-09-21 20:40:33,302 - DEBUG - /opt/ml/code/yolov5
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/metric-definition-regex.json
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/init-config.json
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/upstreamoutputdataconfig.json
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/resourceconfig.json
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/inputdataconfig.json
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/hyperparameters.json
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/checkpointconfig.json
# 2020-09-21 20:40:33,304 - DEBUG - /opt/ml/input/config/tensorboardoutputconfig.json
# 2020-09-21 20:40:33,305 - DEBUG - /opt/ml/input/data/training
# 2020-09-21 20:40:33,305 - DEBUG - /opt/ml/input/data/checkpoints-manifest
# 2020-09-21 20:40:33,305 - DEBUG - /opt/ml/input/data/training/validating
# 2020-09-21 20:40:33,305 - DEBUG - /opt/ml/input/data/training/training
# 2020-09-21 20:40:33,322 - INFO - Running training script
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-09-21 20:40:34,981 - INFO - Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
# 2020-09-21 20:40:34,981 - INFO - Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
# 2020-09-21 20:40:34,981 - INFO -
# 2020-09-21 20:40:34,981 - INFO -
# Traceback (most recent call last):
#   File "code/yolov5/train.py", line 445, in <module>
#     assert torch.cuda.device_count() > opt.local_rank
# AssertionError
# 2020-09-21 20:40:36,960 - INFO - Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
# 2020-09-21 20:40:36,960 - INFO - Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
# 2020-09-21 20:40:36,960 - INFO -
# 2020-09-21 20:40:36,960 - INFO -
# Traceback (most recent call last):
#   File "code/yolov5/train.py", line 445, in <module>
#     assert torch.cuda.device_count() > opt.local_rank
# AssertionError
#
# 2020-09-21 20:40:31 Training - Training image download completed. Training in progress.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-9932e2ae5f85> in <module>
#      30
#      31 #yolov3_estimator.fit(job_name=base_job_name, wait=True)
# ---> 32 yolov3_estimator.fit(inputs={"training": s3_uri_data}, job_name=base_job_name, wait=True)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     497         self.jobs.append(self.latest_training_job)
#     498         if wait:
# --> 499             self.latest_training_job.wait(logs=logs)
#     500
#     501     def _compilation_job_name(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1137         # If logs are requested, call logs_for_jobs.
#    1138         if logs != "None":
# -> 1139             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1140         else:
#    1141             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3035                 break
#    3036
# -> 3037             time.sleep(poll)
#    3038
#    3039             if state == LogState.JOB_COMPLETE:
#
# KeyboardInterrupt:
