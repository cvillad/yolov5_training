# %% [markdown]
# ## Building and pushing image to an EC Repository

# %%
# !cd .. && scripts/build_and_push.sh
# Out:
# scripts/build_and_push.sh: line 1: ·!/bin/bash: No such file or directory
# ECR Login
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Building image
# Sending build context to Docker daemon  2.457GB
# Step 1/9 : FROM nvcr.io/nvidia/pytorch:20.08-py3
#  ---> c710aa2340b4
# Step 2/9 : ENV PYTHONDONTWRITEBYTECODE=1
#  ---> Using cache
#  ---> 295935347b1d
# Step 3/9 : ENV PYTHONUNBUFFERED=1
#  ---> Using cache
#  ---> 26565b10a721
# Step 4/9 : RUN apt-get update && apt-get install -y --no-install-recommends nginx curl
#  ---> Using cache
#  ---> 445f2f54008a
# Step 5/9 : WORKDIR /opt/ml/
#  ---> Using cache
#  ---> 3d11e3dd1845
# Step 6/9 : RUN pip install sagemaker-training
#  ---> Using cache
#  ---> 84aae73d542a
# Step 7/9 : COPY src/ /opt/ml/code/
#  ---> Using cache
#  ---> 6c5bbc60bb6b
# Step 8/9 : ENV SAGEMAKER_PROGRAM train
#  ---> Using cache
#  ---> e87daa887de6
# Step 9/9 : ENV PATH="/opt/ml/code:${PATH}"
#  ---> Using cache
#  ---> a7bf32d3121a
# Successfully built a7bf32d3121a
# Successfully tagged train:latest
# Pushing to ECR
# The push refers to repository [430127992102.dkr.ecr.us-west-2.amazonaws.com/yolov5_train]
#
# d646597d: Preparing
# f47f8f6d: Preparing
# 1cb52a4f: Preparing
# e3646006: Preparing
# 535cf0b1: Preparing
# f2fc23be: Preparing
# f1144bfa: Preparing
# 4a3f2ae3: Preparing
# 8bfdeee7: Preparing
# bedfd29d: Preparing
# 3a848754: Preparing
# 79876d58: Preparing
# 6cc777e6: Preparing
# 481d042b: Preparing
# 2d1617bd: Preparing
# 5b178613: Preparing
# 20ece1bb: Preparing
# d45c9936: Preparing
# bcc85b52: Preparing
# 1df9aa18: Preparing
# 757968f7: Preparing
# c8ca60ec: Preparing
# 01b6160f: Preparing
# 08e715aa: Preparing
# 38ca324c: Preparing
# 05efbb85: Preparing
# ef29593c: Preparing
# c1b005d0: Preparing
# 3347c77e: Preparing
# 73b91957: Preparing
# 6bba3a54: Preparing
# d305b6fe: Preparing
# 34539c4b: Preparing
# 8e883ce0: Preparing
# 3105ea49: Preparing
# fd860433: Preparing
# 196d29b9: Preparing
# dc9d77d9: Preparing
# 87a0f336: Preparing
# 76287df5: Preparing
# 7aea68cd: Preparing
# 1ccf7ee0: Preparing
# 51c2f8ad: Preparing
# 2a1a6205: Preparing
# 546ec635: Preparing
# 8b3c8971: Preparing
# 3a2b059b: Preparing
# 30055b29: Preparing
# f1b5f44c: Preparing
# b917ef50: Preparing
# 3c4877ef: Preparing
# b71a5be7: Preparing
# 4487ecb7: Preparing
# 5173a9ae: Preparing
# c169ba53: Preparing
# 36b4dc3d: Preparing
# 877f8a1f: Preparing
# 146f5dbd: Preparing
# f9a74649: Preparing
# da143c91: Preparing
# 287e1f04: Preparing
# 68776582: Layer already exists latest: digest: sha256:1d087815929d5416f5ac1e73b0c43987ca703db6381147656b98be7607f7cd1b size: 13338

# %% [markdown]
# ## Sagemaker config

# %%
from sagemaker.session import get_execution_role, Session
import os

sagemaker_role = get_execution_role()
sagemaker_session = Session()

# %%
from time import gmtime, strftime

bucket_name = sagemaker_session.default_bucket()
key_name = "TiendaApp"
s3_uri_data = "s3://{}/{}/{}/".format(bucket_name, key_name, "data")
s3_uri_output = "s3://{}/{}/{}/".format(bucket_name, key_name, "model")
s3_uri_checkpoint = "s3://{}/{}/{}".format(bucket_name, key_name, "checkpoints")
s3_output_path_tensorboard = "s3://{}/{}/{}".format(bucket_name, key_name, "tensorboard")
s3_uri_input_model = "s3://{}/{}/{}/".format(bucket_name, key_name, "input")

account = sagemaker_session.boto_session.client('sts').get_caller_identity()['Account']
region = sagemaker_session.boto_session.region_name
image_name = "yolov5_train"
image_uri = "{0}.dkr.ecr.{1}.amazonaws.com/{2}".format(account, region, image_name)

base_job_name = "test-training-job-{}".format(strftime("%Y-%m-%d-%H-%M-%S", gmtime()))
os.environ["account"] = account
os.environ["s3_uri"] = s3_uri_data

print("Training Job name : {}".format(base_job_name))
print("S3 uri input: {}".format(s3_uri_data))
print("S3 uri output: {}".format(s3_uri_output))
print("image uri: {}".format(image_uri))
#!aws s3 ls $s3_uri
#!aws ecr describe-repositories --registry-id $account
# Out:
# Training Job name : test-training-job-2020-10-01-20-33-51
# S3 uri input: s3://sagemaker-us-west-2-430127992102/TiendaApp/data/
# S3 uri output: s3://sagemaker-us-west-2-430127992102/TiendaApp/model/
# image uri: 430127992102.dkr.ecr.us-west-2.amazonaws.com/yolov5_train

# %% [markdown]
# ## Starting a sagemaker training job

# %%
from sagemaker.estimator import Estimator
from sagemaker.debugger import TensorBoardOutputConfig

tensorboard_output_config = TensorBoardOutputConfig(
    s3_output_path=s3_output_path_tensorboard,
    container_local_output_path="/opt/ml/output/tensorboard"
)

prefix = "/opt/ml"

hyperparameters = {"epochs": 1, 
                   "batch-size": 32, 
                   "weights": os.path.join(prefix, "input/data/model/yolov5m.pt"),
                   "cfg": os.path.join(prefix, "code/models/yolov5m.yaml")}

metric_definitions = [{"Name": "train:error", "Regex": "\S*train_error=([0-9\.]+)"},
                     {"Name": "val:error", "Regex": "\S*val_error=([0-9\\.]+)"}]
checkpoint_local_path = "/opt/ml/checkpoints/"

yolov3_estimator = Estimator(image_name=image_uri, 
                            role=sagemaker_role,
                            train_max_run=172800,
                            output_path=s3_uri_output,
                            train_instance_count=1,
                            train_instance_type="ml.g4dn.xlarge",
                            #train_instance_type="ml.m5.xlarge",
                            train_volume_size=35,
                            model_uri = s3_uri_input_model,
                            model_channel_name = 'model',
                            sagemaker_session=sagemaker_session,
                            tensorboard_output_config = tensorboard_output_config,
                            enable_sagemaker_metrics = True,
                            metric_definitions = metric_definitions,
                            checkpoint_s3_uri = s3_uri_checkpoint,
                            checkpoint_local_path = checkpoint_local_path,
                            base_job_name = base_job_name,
                            hyperparameters = hyperparameters,
                            tags=[{"Key": "Name", "Value": "test-job"},
                             {"Key": "Description", "Value": "Test training job"}])


yolov3_estimator.fit(inputs={"training": s3_uri_data}, job_name=base_job_name, wait=True)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-10-01 20:33:51 Starting - Starting the training job...
# 2020-10-01 20:33:55 Starting - Launching requested ML instances......
# 2020-10-01 20:34:57 Starting - Preparing the instances for training...
# 2020-10-01 20:35:47 Downloading - Downloading input data.........
# 2020-10-01 20:37:15 Training - Downloading the training image.........................=============
# == PyTorch ==
# =============
#
# NVIDIA Release 20.08 (build 15516749)
# PyTorch Version 1.7.0a0+8deb4fe
#
# Container image Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#
# Copyright (c) 2014-2020 Facebook Inc.
# Copyright (c) 2011-2014 Idiap Research Institute (Ronan Collobert)
# Copyright (c) 2012-2014 Deepmind Technologies    (Koray Kavukcuoglu)
# Copyright (c) 2011-2012 NEC Laboratories America (Koray Kavukcuoglu)
# Copyright (c) 2011-2013 NYU                      (Clement Farabet)
# Copyright (c) 2006-2010 NEC Laboratories America (Ronan Collobert, Leon Bottou, Iain Melvin, Jason Weston)
# Copyright (c) 2006      Idiap Research Institute (Samy Bengio)
# Copyright (c) 2001-2004 Idiap Research Institute (Ronan Collobert, Samy Bengio, Johnny Mariethoz)
# Copyright (c) 2015      Google Inc.
# Copyright (c) 2015      Yangqing Jia
# Copyright (c) 2013-2016 The Caffe contributors
# All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION.  All rights reserved.
# NVIDIA modifications are covered by the license terms that apply to the underlying project or file.
#
# NOTE: Legacy NVIDIA Driver detected.  Compatibility mode ENABLED.
#
# NOTE: MOFED driver for multi-node communication was not detected.
#       Multi-node communication performance may be reduced.
#
# 2020-10-01 20:41:23,645 - INFO - Container structure
# 2020-10-01 20:41:23,645 - DEBUG - /opt/ml/output
# 2020-10-01 20:41:23,645 - DEBUG - /opt/ml/model
# 2020-10-01 20:41:23,645 - DEBUG - /opt/ml/checkpoints
# 2020-10-01 20:41:23,645 - DEBUG - /opt/ml/code
# 2020-10-01 20:41:23,645 - DEBUG - /opt/ml/input
# 2020-10-01 20:41:23,645 - DEBUG - /opt/ml/output/data
# 2020-10-01 20:41:23,645 - DEBUG - /opt/ml/output/profiler
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/output/tensorboard
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/output/metrics
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/output/metrics/sagemaker
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/checkpoints/ckpt_epoch1.pt
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/checkpoints/ckpt.pt
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/checkpoints/ckpt_epoch4.pt
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/checkpoints/ckpt_epoch0.pt
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/code/weights
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/code/utils
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/code/models
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/code/yolo.py
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/code/train
# 2020-10-01 20:41:23,646 - DEBUG - /opt/ml/code/test.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/weights/download_weights.sh
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/utils/logger.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/utils/general.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/utils/evolve.sh
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/utils/datasets.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/utils/__init__.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/utils/torch_utils.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/utils/google_utils.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/models/hub
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/models/yolov5s.yaml
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/models/yolo.py
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/models/yolov5x.yaml
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/models/yolov5m.yaml
# 2020-10-01 20:41:23,647 - DEBUG - /opt/ml/code/models/experimental.py
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/code/models/__init__.py
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/code/models/yolov5l.yaml
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/code/models/common.py
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/code/models/hub/yolov3-spp.yaml
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/code/models/hub/yolov5-panet.yaml
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/code/models/hub/yolov5-fpn.yaml
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/input/data
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/input/config
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/input/data/model
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/input/data/training
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/input/data/checkpoints-manifest
# 2020-10-01 20:41:23,648 - DEBUG - /opt/ml/input/data/model-manifest
# 2020-10-01 20:41:23,649 - DEBUG - /opt/ml/input/data/model/yolov5x.pt
# 2020-10-01 20:41:23,649 - DEBUG - /opt/ml/input/data/model/yolov5l.pt
# 2020-10-01 20:41:23,649 - DEBUG - /opt/ml/input/data/model/yolov5s.pt
# 2020-10-01 20:41:23,649 - DEBUG - /opt/ml/input/data/model/yolov5m.pt
# 2020-10-01 20:41:23,649 - DEBUG - /opt/ml/input/data/training/training
# 2020-10-01 20:41:23,649 - DEBUG - /opt/ml/input/data/training/validating
# 2020-10-01 20:41:23,672 - DEBUG - /opt/ml/input/config/checkpointconfig.json
# 2020-10-01 20:41:23,673 - DEBUG - /opt/ml/input/config/tensorboardoutputconfig.json
# 2020-10-01 20:41:23,673 - DEBUG - /opt/ml/input/config/resourceconfig.json
# 2020-10-01 20:41:23,673 - DEBUG - /opt/ml/input/config/init-config.json
# 2020-10-01 20:41:23,673 - DEBUG - /opt/ml/input/config/metric-definition-regex.json
# 2020-10-01 20:41:23,673 - DEBUG - /opt/ml/input/config/upstreamoutputdataconfig.json
# 2020-10-01 20:41:23,673 - DEBUG - /opt/ml/input/config/inputdataconfig.json
# 2020-10-01 20:41:23,673 - DEBUG - /opt/ml/input/config/hyperparameters.json
# 2020-10-01 20:41:23,673 - INFO - Running training script
# 2020-10-01 20:41:28,137 - INFO - Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
# 2020-10-01 20:41:28,137 - INFO -
# 2020-10-01 20:41:28,139 - INFO - Namespace(adam=False, batch_size=32, bucket='', cache_images=False, cfg='/opt/ml/code/models/yolov5m.yaml', checkpoints='/opt/ml/checkpoints', data='/opt/ml/input/data/training/data.yaml', device='', epochs=1, evolve=False, global_rank=-1, hyp='/opt/ml/input/data/training/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, logdir='/opt/ml/output/tensorboard', model='/opt/ml/model', multi_scale=False, name='', noautoanchor=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='/opt/ml/input/data/model/yolov5m.pt', workers=8, world_size=1)
# 2020-10-01 20:41:28,143 - INFO - Start Tensorboard with "tensorboard --logdir /opt/ml/output/tensorboard", view at http://localhost:6006/
# 2020-10-01 20:41:28,144 - INFO - Hyperparameters {'lr0': 0.01, 'lrf': 0.2, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'giou': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0}
# 2020-10-01 20:41:32,332 - INFO -
#                  from  n    params  module                                  arguments
# 2020-10-01 20:41:32,350 - INFO -   0                -1  1      5280  models.common.Focus                     [3, 48, 3]
# 2020-10-01 20:41:32,351 - INFO -   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
# 2020-10-01 20:41:32,354 - INFO -   2                -1  1     67680  models.common.BottleneckCSP             [96, 96, 2]
# 2020-10-01 20:41:32,355 - INFO -   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
# 2020-10-01 20:41:32,363 - INFO -   4                -1  1    639168  models.common.BottleneckCSP             [192, 192, 6]
# 2020-10-01 20:41:32,367 - INFO -   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
# 2020-10-01 20:41:32,386 - INFO -   6                -1  1   2550144  models.common.BottleneckCSP             [384, 384, 6]
# 2020-10-01 20:41:32,404 - INFO -   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
# 2020-10-01 20:41:32,415 - INFO -   8                -1  1   1476864  models.common.SPP                       [768, 768, [5, 9, 13]]
# 2020-10-01 20:41:32,449 - INFO -   9                -1  1   4283136  models.common.BottleneckCSP             [768, 768, 2, False]
# 2020-10-01 20:41:32,451 - INFO -  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
# 2020-10-01 20:41:32,451 - INFO -  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
# 2020-10-01 20:41:32,452 - INFO -  12           [-1, 6]  1         0  models.common.Concat                    [1]
# 2020-10-01 20:41:32,463 - INFO -  13                -1  1   1219968  models.common.BottleneckCSP             [768, 384, 2, False]
# 2020-10-01 20:41:32,464 - INFO -  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
# 2020-10-01 20:41:32,464 - INFO -  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
# 2020-10-01 20:41:32,464 - INFO -  16           [-1, 4]  1         0  models.common.Concat                    [1]
# 2020-10-01 20:41:32,469 - INFO -  17                -1  1    305856  models.common.BottleneckCSP             [384, 192, 2, False]
# 2020-10-01 20:41:32,472 - INFO -  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
# 2020-10-01 20:41:32,472 - INFO -  19          [-1, 14]  1         0  models.common.Concat                    [1]
# 2020-10-01 20:41:32,482 - INFO -  20                -1  1   1072512  models.common.BottleneckCSP             [384, 384, 2, False]
# 2020-10-01 20:41:32,492 - INFO -  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
# 2020-10-01 20:41:32,492 - INFO -  22          [-1, 10]  1         0  models.common.Concat                    [1]
# 2020-10-01 20:41:32,524 - INFO -  23                -1  1   4283136  models.common.BottleneckCSP             [768, 768, 2, False]
# 2020-10-01 20:41:32,531 - INFO -  24      [17, 20, 23]  1    101025  models.yolo.Detect                      [20, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# 2020-10-01 20:41:32,780 - INFO - Model Summary: 263 layers, 2.15626e+07 parameters, 2.15626e+07 gradients
#
# 2020-10-01 20:41:32,869 - INFO - Transferred 506/514 items from /opt/ml/input/data/model/yolov5m.pt
# 2020-10-01 20:41:32,870 - INFO - Optimizer groups: 86 .bias, 94 conv.weight, 83 other
# #0150it [00:00, ?it/s]#015Scanning labels /opt/ml/input/data/training/training.cache (1604 found, 0 missing, 0 empty, 0 duplicate, for 3375 images): 1604it [00:00, 16031.99it/s]#015Scanning labels /opt/ml/input/data/training/training.cache (3152 found, 0 missing, 0 empty, 4 duplicate, for 3375 images): 3152it [00:00, 15861.77it/s]#015Scanning labels /opt/ml/input/data/training/training.cache (3375 found, 0 missing, 0 empty, 4 duplicate, for 3375 images): 3375it [00:00, 15562.18it/s]
# #0150it [00:00, ?it/s]#015Scanning labels /opt/ml/input/data/training/validating.cache (473 found, 0 missing, 0 empty, 2 duplicate, for 2125 images): 473it [00:00, 4673.84it/s]#015Scanning labels /opt/ml/input/data/training/validating.cache (952 found, 0 missing, 0 empty, 2 duplicate, for 2125 images): 952it [00:00, 4707.90it/s]#015Scanning labels /opt/ml/input/data/training/validating.cache (1962 found, 0 missing, 0 empty, 2 duplicate, for 2125 images): 1962it [00:00, 5605.00it/s]#015Scanning labels /opt/ml/input/data/training/validating.cache (2125 found, 0 missing, 0 empty, 2 duplicate, for 2125 images): 2125it [00:00, 6678.29it/s]
# 2020-10-01 20:41:36,713 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0.
# 2020-10-01 20:41:36,715 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 2020-10-01 20:41:36,716 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2020-10-01 20:41:36,716 - DEBUG - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,716 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,717 - DEBUG - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,717 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,717 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2020-10-01 20:41:36,717 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,718 - DEBUG - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,718 - DEBUG - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,718 - DEBUG - findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,718 - DEBUG - findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,718 - DEBUG - findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,719 - DEBUG - findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,719 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,719 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2020-10-01 20:41:36,720 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2020-10-01 20:41:36,720 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2020-10-01 20:41:36,720 - DEBUG - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,720 - DEBUG - findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,723 - DEBUG - findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,723 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,723 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 2020-10-01 20:41:36,723 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 2020-10-01 20:41:36,724 - DEBUG - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,724 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,724 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-10-01 20:41:36,724 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 2020-10-01 20:41:36,725 - DEBUG - findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,725 - DEBUG - findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,725 - DEBUG - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,725 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2020-10-01 20:41:36,726 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,726 - DEBUG - findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,726 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2020-10-01 20:41:36,727 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,727 - DEBUG - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,727 - DEBUG - findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,728 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2020-10-01 20:41:36,728 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,729 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2020-10-01 20:41:36,729 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,729 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:41:36,731 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:41:36,731 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0 to DejaVu Sans ('/opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# Analyzing anchors... anchors/target = 4.64, Best Possible Recall (BPR) = 0.9998
# 2020-10-01 20:41:41,382 - INFO - Image sizes 640 train, 640 test
# Using 4 dataloader workers
# Logging results to /opt/ml/output/tensorboard/exp0
# Starting training for 1 epochs...
#
# 2020-10-01 20:42:16 Training - Training image download completed. Training in progress.2020-10-01 20:49:08,889 - INFO - Batch 0/67 completed
# 2020-10-01 20:49:15,311 - INFO - Batch 1/67 completed
# 2020-10-01 20:49:15,952 - INFO - Batch 2/67 completed
# 2020-10-01 20:49:19,522 - INFO - Batch 3/67 completed
# 2020-10-01 20:49:20,130 - INFO - Batch 4/67 completed
# 2020-10-01 20:49:23,786 - INFO - Batch 5/67 completed
# 2020-10-01 20:49:24,328 - INFO - Batch 6/67 completed
# 2020-10-01 20:49:24,752 - INFO - Batch 7/67 completed
# 2020-10-01 20:49:25,089 - INFO - Batch 8/67 completed
# 2020-10-01 20:49:25,510 - INFO - Batch 9/67 completed
# 2020-10-01 20:49:26,153 - INFO - Batch 10/67 completed
# 2020-10-01 20:49:27,098 - INFO - Batch 11/67 completed
# 2020-10-01 20:49:28,426 - INFO - Batch 12/67 completed
# 2020-10-01 20:49:29,647 - INFO - Batch 13/67 completed
# 2020-10-01 20:49:31,951 - INFO - Batch 14/67 completed
# 2020-10-01 20:49:33,166 - INFO - Batch 15/67 completed
# 2020-10-01 20:49:34,388 - INFO - Batch 16/67 completed
# 2020-10-01 20:49:34,825 - INFO - Batch 17/67 completed
# 2020-10-01 20:49:38,509 - INFO - Batch 18/67 completed
# 2020-10-01 20:49:40,163 - INFO - Batch 19/67 completed
# 2020-10-01 20:49:40,791 - INFO - Batch 20/67 completed
# 2020-10-01 20:49:41,684 - INFO - Batch 21/67 completed
# 2020-10-01 20:49:45,599 - INFO - Batch 22/67 completed
# 2020-10-01 20:49:46,884 - INFO - Batch 23/67 completed
# 2020-10-01 20:49:47,895 - INFO - Batch 24/67 completed
# 2020-10-01 20:49:48,902 - INFO - Batch 25/67 completed
# 2020-10-01 20:49:52,945 - INFO - Batch 26/67 completed
# 2020-10-01 20:49:53,835 - INFO - Batch 27/67 completed
# 2020-10-01 20:49:55,101 - INFO - Batch 28/67 completed
# 2020-10-01 20:49:55,685 - INFO - Batch 29/67 completed
# 2020-10-01 20:50:00,099 - INFO - Batch 30/67 completed
# 2020-10-01 20:50:00,731 - INFO - Batch 31/67 completed
# 2020-10-01 20:50:01,940 - INFO - Batch 32/67 completed
# 2020-10-01 20:50:02,874 - INFO - Batch 33/67 completed
# 2020-10-01 20:50:06,803 - INFO - Batch 34/67 completed
# 2020-10-01 20:50:07,860 - INFO - Batch 35/67 completed
# 2020-10-01 20:50:08,990 - INFO - Batch 36/67 completed
# 2020-10-01 20:50:09,490 - INFO - Batch 37/67 completed
# 2020-10-01 20:50:15,292 - INFO - Batch 38/67 completed
# 2020-10-01 20:50:17,114 - INFO - Batch 39/67 completed
# 2020-10-01 20:50:19,884 - INFO - Batch 40/67 completed
# 2020-10-01 20:50:20,423 - INFO - Batch 41/67 completed
# 2020-10-01 20:50:22,078 - INFO - Batch 42/67 completed
# 2020-10-01 20:50:22,824 - INFO - Batch 43/67 completed
# 2020-10-01 20:50:23,209 - INFO - Batch 44/67 completed
# 2020-10-01 20:50:23,973 - INFO - Batch 45/67 completed
# 2020-10-01 20:50:28,820 - INFO - Batch 46/67 completed
# 2020-10-01 20:50:29,655 - INFO - Batch 47/67 completed
# 2020-10-01 20:50:31,002 - INFO - Batch 48/67 completed
# 2020-10-01 20:50:31,551 - INFO - Batch 49/67 completed
# 2020-10-01 20:50:36,306 - INFO - Batch 50/67 completed
# 2020-10-01 20:50:36,674 - INFO - Batch 51/67 completed
# 2020-10-01 20:50:37,148 - INFO - Batch 52/67 completed
# 2020-10-01 20:50:38,176 - INFO - Batch 53/67 completed
# 2020-10-01 20:50:42,800 - INFO - Batch 54/67 completed
# 2020-10-01 20:50:43,113 - INFO - Batch 55/67 completed
# 2020-10-01 20:50:43,443 - INFO - Batch 56/67 completed
# 2020-10-01 20:50:46,853 - INFO - Batch 57/67 completed
#
# 2020-10-01 20:51:01 Uploading - Uploading generated training model2020-10-01 20:50:47,246 - INFO - Batch 58/67 completed
# 2020-10-01 20:50:47,694 - INFO - Batch 59/67 completed
# 2020-10-01 20:50:48,123 - INFO - Batch 60/67 completed
# 2020-10-01 20:50:48,661 - INFO - Batch 61/67 completed
# 2020-10-01 20:50:49,051 - INFO - Batch 62/67 completed
# 2020-10-01 20:50:49,499 - INFO - Batch 63/67 completed
# 2020-10-01 20:50:49,913 - INFO - Batch 64/67 completed
# 2020-10-01 20:50:50,440 - INFO - Batch 65/67 completed
# 2020-10-01 20:50:52,479 - INFO - Batch 66/67 completed
#                  all    2.12e+03    5.36e+03      0.0539       0.255      0.0867      0.0344
# 2020-10-01 20:50:53,841 - INFO - Epoch 0 completed
# 2020-10-01 20:50:54,120 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=13.2.
# 2020-10-01 20:50:54,120 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 2020-10-01 20:50:54,121 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2020-10-01 20:50:54,121 - DEBUG - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,122 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,122 - DEBUG - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,123 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,123 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2020-10-01 20:50:54,125 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,126 - DEBUG - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,126 - DEBUG - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,126 - DEBUG - findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,127 - DEBUG - findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,127 - DEBUG - findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,127 - DEBUG - findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,128 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,128 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2020-10-01 20:50:54,129 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2020-10-01 20:50:54,129 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2020-10-01 20:50:54,129 - DEBUG - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,130 - DEBUG - findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,130 - DEBUG - findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,130 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,131 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 2020-10-01 20:50:54,131 - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 2020-10-01 20:50:54,131 - DEBUG - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,132 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,132 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-10-01 20:50:54,132 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 2020-10-01 20:50:54,132 - DEBUG - findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,132 - DEBUG - findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,133 - DEBUG - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,133 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2020-10-01 20:50:54,133 - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,133 - DEBUG - findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,133 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2020-10-01 20:50:54,134 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,134 - DEBUG - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,134 - DEBUG - findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,134 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2020-10-01 20:50:54,135 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,135 - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2020-10-01 20:50:54,135 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,135 - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-01 20:50:54,136 - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2020-10-01 20:50:54,137 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=13.2 to DejaVu Sans ('/opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# 2020-10-01 20:50:54,846 - INFO - 1 epochs completed in 0.154 hours.
#
# 2020-10-01 20:50:57,403 - INFO - Training completed
#
# 2020-10-01 20:52:28 Completed - Training job completed
# Training seconds: 1001
# Billable seconds: 1001
